# %% [markdown]
# # <font color='blue'>Deals e Leads</font>
# ________________
#
# <p>Autor: Paulo Alozen</p>
# <p>Data: 12.02.2019</p>
# <p>Data Prevista Entrega: 01.04.2019</p>

# %% [markdown]
# ## Descrição do problema:
# ______
# <p> Utilizar os dados de Deals da área comercial em conjunto com os dados de Leads da área de marketing para
# atingir os seguinte objetivos:</p>
#
# <p>1) Classificar em grupos por semelhança, os dados de deals/leads (Clusterização);</p>
# <p>2) Definir qual os principais fatores para a conversão dos leads por vendas;</p>
# <p>3) Modelo com o score de probabilidade para converter um lead em uma venda;</p>

# %% [markdown]
# ## <font color='blue'> Índice:</font>
#
# * [1. Leitura e entendimento do arquivo](#leitura)
# * [2. Ajuste de nome e dos tipos de dados](#ajuste_dados)
# * [3. Derivação de novos campos](#derivate_fields)
# * [4. Eliminação de outliers](#outliers)

# %% [markdown]
# <h2><a id="leitura" class="anchor">1 - Leitura e Entendimento do Arquivo</a></h2>

# %% [markdown]
# Para entender o arquivo, nós podemos verificar algumas propriedades do mesmo, como:
# * quantidade de linhas e colunas;
# * visualizar as primeiras linhas do arquivo;
# * verificar o tipos de variáveis presentes no arquivo.

# %%
import pandas as pd

pd.set_option('display.max_columns', 300)
pd.set_option('display.max_rows', 300)

df_deals = pd.read_csv('arquivos/deals.csv', sep=';')
print(f'Linhas e colunas: {df_deals.shape}\n')
print(f'Tipos de dados de cada coluna: \n{df_deals.dtypes}')
df_deals.head()
# Out:
# Linhas e colunas: (1843, 45)
#
# Tipos de dados de cada coluna:
# Negócio - Stage                          object
# Negócio - Title                          object
# Negócio - Value                          object
# Negócio - Implementação                 float64
# Negócio - Volume de admissões mensal    float64
# Negócio - Número de funcionários        float64
# Negócio - Deal created                   object
# Negócio - Won time                       object
# Negócio - Owner                          object
# Negócio - Pipeline                       object
# Negócio - Lost reason                    object
# Negócio - Interesse                      object
# Negócio - Origem do deal                 object
# Negócio - Status                         object
# Negócio - Motivo de perda detalhado      object
# Negócio - Lost time                      object
# Negócio - Last activity date             object
# Negócio - Last email received            object
# Negócio - Last email sent                object
# Negócio - Last stage change              object
# Negócio - Mercado                        object
# Negócio - Expected close date            object
# Negócio - Expectativa de Produto         object
# Negócio - Activities to do                int64
# Negócio - Banco Parceiro Pgt.            object
# Negócio - Contact person                 object
# Negócio - Creator                        object
# Negócio - Deal closed on                 object
# Negócio - Done activities                 int64
# Negócio - Email messages count            int64
# Negócio - Next activity date             object
# Negócio - Organization                   object
# Negócio - Probability                   float64
# Negócio - Qtd. CLTs                      object
# Negócio - Sistema de Folha de Pgto       object
# Negócio - Sistema de Ponto               object
# Negócio - Source                        float64
# Negócio - Source.1                      float64
# Negócio - Tem adiantamento?              object
# Negócio - Tem conta-salário?             object
# Negócio - Total activities                int64
# Negócio - Update time                    object
# Negócio - Currency                       object
# Negócio - Visible to                     object
# Negócio - Weighted value                 object
# dtype: object
#       Negócio - Stage         Negócio - Title Negócio - Value  \
# 0         Compromisso                Ipiranga    1.400,00 BRL
# 1  Proposta Comercial              Lab. Exame    1.000,00 BRL
# 2             Conexão                 DTintas    1.950,00 BRL
# 3  Proposta Comercial  [Contably] Três Contas      900,00 BRL
# 4  Proposta Comercial      [Contably] Almeida      450,00 BRL
#
#    Negócio - Implementação  Negócio - Volume de admissões mensal  \
# 0                      NaN                                  50.0
# 1                   2500.0                                  12.0
# 2                      NaN                                   5.0
# 3                   3500.0                                   3.0
# 4                      NaN                                  20.0
#
#    Negócio - Número de funcionários Negócio - Deal created Negócio - Won time  \
# 0                            3500.0    2018-11-06 18:45:30                NaN
# 1                             105.0    2018-12-03 14:39:50                NaN
# 2                              35.0    2019-01-21 16:33:38                NaN
# 3                             150.0    2018-12-10 17:30:58                NaN
# 4                              40.0    2018-12-10 17:33:11                NaN
#
#     Negócio - Owner Negócio - Pipeline        Negócio - Lost reason  \
# 0   Guilherme Salam       Canal Direto  Não atendeu as expectativas
# 1    Adriana Campos       Canal Direto  Não atendeu as expectativas
# 2  Tamiris Januário       Canal Direto               Não tem budget
# 3   José Luiz Souza       Canal Direto  parceiro não avançou com op
# 4   José Luiz Souza       Canal Direto  parceiro não avançou com op
#
#          Negócio - Interesse Negócio - Origem do deal Negócio - Status  \
# 0                   Admissão                  Inbound             Lost
# 1             Plano Completo                  Inbound             Lost
# 2  Holerites, Plano Completo                  Inbound             Lost
# 3             Plano Completo                Parcerias             Lost
# 4             Plano Completo                Parcerias             Lost
#
#                  Negócio - Motivo de perda detalhado  Negócio - Lost time  \
# 0                           Precisa integrar com FPW  2019-01-23 18:03:12
# 1  Queria um sistema que subisse recibo de ferias...  2019-01-23 16:51:33
# 2                                                NaN  2019-01-23 11:52:06
# 3                        parceiro não avançou com op  2019-01-23 11:10:49
# 4                        parceiro não avançou com op  2019-01-23 11:10:35
#
#   Negócio - Last activity date Negócio - Last email received  \
# 0                   2018-12-11           2018-11-14 18:12:45
# 1                   2019-01-22           2019-01-15 13:35:52
# 2                   2019-01-22           2019-01-22 22:01:58
# 3                   2019-01-21           2018-12-10 11:46:57
# 4                   2019-01-21           2018-12-20 09:38:43
#
#   Negócio - Last email sent Negócio - Last stage change Negócio - Mercado  \
# 0       2018-11-22 19:40:22         2018-11-12 17:12:05            Varejo
# 1       2019-01-15 15:11:14         2018-12-10 10:54:25             Saúde
# 2       2019-01-23 11:51:43                         NaN               NaN
# 3       2018-12-05 16:50:12         2018-12-10 17:40:36       Educacional
# 4       2018-12-19 11:35:09         2018-12-10 17:34:26               NaN
#
#   Negócio - Expected close date  \
# 0                    2019-02-28
# 1                    2019-01-31
# 2                    2019-02-28
# 3                    2018-12-31
# 4                    2018-12-31
#
#                     Negócio - Expectativa de Produto  \
# 0                                                NaN
# 1  Férias - Recibo de férias, Férias - Aviso sobr...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Negócio - Activities to do Negócio - Banco Parceiro Pgt.  \
# 0                           1                           NaN
# 1                           0                           NaN
# 2                           0                           NaN
# 3                           0                           NaN
# 4                           0                           NaN
#
#   Negócio - Contact person  Negócio - Creator Negócio - Deal closed on  \
# 0             Alice Xavier    Guilherme Salam      2019-01-23 18:03:12
# 1     Elizângela Alvarenga  Henrique Carvalho      2019-01-23 16:51:33
# 2                   Raquel   Tamiris Januário      2019-01-23 11:52:06
# 3          Rafael Contably    José Luiz Souza      2019-01-23 11:10:49
# 4          Rafael Contably    José Luiz Souza      2019-01-23 11:10:35
#
#    Negócio - Done activities  Negócio - Email messages count  \
# 0                         15                              18
# 1                         12                               8
# 2                          6                               2
# 3                          3                               0
# 4                          3                               3
#
#   Negócio - Next activity date Negócio - Organization  Negócio - Probability  \
# 0                   2019-02-19               Ipiranga                    NaN
# 1                          NaN             Lab. Exame                    NaN
# 2                          NaN                DTintas                    NaN
# 3                          NaN                Cotably                    NaN
# 4                          NaN                Cotably                    NaN
#
#   Negócio - Qtd. CLTs Negócio - Sistema de Folha de Pgto  \
# 0                 NaN                                FPW
# 1                 NaN              Contabilidade Externa
# 2                 NaN              Contabilidade Externa
# 3                 NaN                                NaN
# 4                 NaN                                NaN
#
#   Negócio - Sistema de Ponto  Negócio - Source  Negócio - Source.1  \
# 0                        NaN               NaN                 NaN
# 1                        NaN               NaN                 NaN
# 2                        NaN               NaN                 NaN
# 3                        NaN               NaN                 NaN
# 4                        NaN               NaN                 NaN
#
#   Negócio - Tem adiantamento? Negócio - Tem conta-salário?  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    Negócio - Total activities Negócio - Update time Negócio - Currency  \
# 0                          16   2019-01-23 18:03:25                BRL
# 1                          12   2019-01-23 17:01:58                BRL
# 2                           6   2019-01-23 11:52:06                BRL
# 3                           3   2019-01-23 11:10:53                BRL
# 4                           3   2019-01-23 11:10:38                BRL
#
#   Negócio - Visible to Negócio - Weighted value
# 0       Entire company               532,00 BRL
# 1       Entire company               540,00 BRL
# 2       Entire company               351,00 BRL
# 3       Entire company               486,00 BRL
# 4       Entire company               243,00 BRL

# %% [markdown]
# <h2><a id="ajuste_dados" class="anchor">2 - Ajustes das variáveis</a></h2>

# %% [markdown]
# Importância do ajuste das variáveis:
#
# * Facilita a visualização os dados de maneiras diferentes;
# * Padroniza alguns tipos de dados para facilitar a análise;
# * Remover variáveis desnecessárias.

# %% [markdown]
# <h3><a id="column_names" class="anchor">2.2 - Ajuste do nome das colunas</a></h3>

# %%
import re
from unicodedata import normalize

for column in df_deals.columns:
    newname = column.split(sep='-')[1]
    newname = newname.strip() # eliminar espaços em branco no ínicio e final
    newname = newname.lower() # converter todas as letras para minúscula
    newname = re.sub(r'[^\w\s]','',newname) # eliminar pontuação
    newname = re.sub(' ','_',newname) # substituir espaço por underscore
    newname = normalize('NFKD', newname).encode('ASCII', 'ignore').decode('ASCII') # eliminar acentos
    df_deals.rename(columns={column:newname},inplace=True)

df_deals.head()
# Out:
#                 stage                   title         value  implementacao  \
# 0         Compromisso                Ipiranga  1.400,00 BRL            NaN
# 1  Proposta Comercial              Lab. Exame  1.000,00 BRL         2500.0
# 2             Conexão                 DTintas  1.950,00 BRL            NaN
# 3  Proposta Comercial  [Contably] Três Contas    900,00 BRL         3500.0
# 4  Proposta Comercial      [Contably] Almeida    450,00 BRL            NaN
#
#    volume_de_admissoes_mensal  numero_de_funcionarios         deal_created  \
# 0                        50.0                  3500.0  2018-11-06 18:45:30
# 1                        12.0                   105.0  2018-12-03 14:39:50
# 2                         5.0                    35.0  2019-01-21 16:33:38
# 3                         3.0                   150.0  2018-12-10 17:30:58
# 4                        20.0                    40.0  2018-12-10 17:33:11
#
#   won_time             owner      pipeline                  lost_reason  \
# 0      NaN   Guilherme Salam  Canal Direto  Não atendeu as expectativas
# 1      NaN    Adriana Campos  Canal Direto  Não atendeu as expectativas
# 2      NaN  Tamiris Januário  Canal Direto               Não tem budget
# 3      NaN   José Luiz Souza  Canal Direto  parceiro não avançou com op
# 4      NaN   José Luiz Souza  Canal Direto  parceiro não avançou com op
#
#                    interesse origem_do_deal status  \
# 0                   Admissão        Inbound   Lost
# 1             Plano Completo        Inbound   Lost
# 2  Holerites, Plano Completo        Inbound   Lost
# 3             Plano Completo      Parcerias   Lost
# 4             Plano Completo      Parcerias   Lost
#
#                            motivo_de_perda_detalhado            lost_time  \
# 0                           Precisa integrar com FPW  2019-01-23 18:03:12
# 1  Queria um sistema que subisse recibo de ferias...  2019-01-23 16:51:33
# 2                                                NaN  2019-01-23 11:52:06
# 3                        parceiro não avançou com op  2019-01-23 11:10:49
# 4                        parceiro não avançou com op  2019-01-23 11:10:35
#
#   last_activity_date  last_email_received      last_email_sent  \
# 0         2018-12-11  2018-11-14 18:12:45  2018-11-22 19:40:22
# 1         2019-01-22  2019-01-15 13:35:52  2019-01-15 15:11:14
# 2         2019-01-22  2019-01-22 22:01:58  2019-01-23 11:51:43
# 3         2019-01-21  2018-12-10 11:46:57  2018-12-05 16:50:12
# 4         2019-01-21  2018-12-20 09:38:43  2018-12-19 11:35:09
#
#      last_stage_change      mercado expected_close_date  \
# 0  2018-11-12 17:12:05       Varejo          2019-02-28
# 1  2018-12-10 10:54:25        Saúde          2019-01-31
# 2                  NaN          NaN          2019-02-28
# 3  2018-12-10 17:40:36  Educacional          2018-12-31
# 4  2018-12-10 17:34:26          NaN          2018-12-31
#
#                               expectativa_de_produto  activities_to_do  \
# 0                                                NaN                 1
# 1  Férias - Recibo de férias, Férias - Aviso sobr...                 0
# 2                                                NaN                 0
# 3                                                NaN                 0
# 4                                                NaN                 0
#
#   banco_parceiro_pgt        contact_person            creator  \
# 0                NaN          Alice Xavier    Guilherme Salam
# 1                NaN  Elizângela Alvarenga  Henrique Carvalho
# 2                NaN                Raquel   Tamiris Januário
# 3                NaN       Rafael Contably    José Luiz Souza
# 4                NaN       Rafael Contably    José Luiz Souza
#
#         deal_closed_on  done_activities  email_messages_count  \
# 0  2019-01-23 18:03:12               15                    18
# 1  2019-01-23 16:51:33               12                     8
# 2  2019-01-23 11:52:06                6                     2
# 3  2019-01-23 11:10:49                3                     0
# 4  2019-01-23 11:10:35                3                     3
#
#   next_activity_date organization  probability qtd_clts  \
# 0         2019-02-19     Ipiranga          NaN      NaN
# 1                NaN   Lab. Exame          NaN      NaN
# 2                NaN      DTintas          NaN      NaN
# 3                NaN      Cotably          NaN      NaN
# 4                NaN      Cotably          NaN      NaN
#
#   sistema_de_folha_de_pgto sistema_de_ponto  source  source1 tem_adiantamento  \
# 0                      FPW              NaN     NaN      NaN              NaN
# 1    Contabilidade Externa              NaN     NaN      NaN              NaN
# 2    Contabilidade Externa              NaN     NaN      NaN              NaN
# 3                      NaN              NaN     NaN      NaN              NaN
# 4                      NaN              NaN     NaN      NaN              NaN
#
#   tem_conta  total_activities          update_time currency      visible_to  \
# 0       NaN                16  2019-01-23 18:03:25      BRL  Entire company
# 1       NaN                12  2019-01-23 17:01:58      BRL  Entire company
# 2       NaN                 6  2019-01-23 11:52:06      BRL  Entire company
# 3       NaN                 3  2019-01-23 11:10:53      BRL  Entire company
# 4       NaN                 3  2019-01-23 11:10:38      BRL  Entire company
#
#   weighted_value
# 0     532,00 BRL
# 1     540,00 BRL
# 2     351,00 BRL
# 3     486,00 BRL
# 4     243,00 BRL

# %% [markdown]
# <h3><a id="drop_fields" class="anchor">2.1 - Remoção de variáveis</a></h3>
#
# Alguns dos motivos que nos levam a remover variáveis:
#
# * Muitos dados faltantes;
# * Falta de padrão nos dados disponíveis;
# * Dados incorretos.

# %% [markdown]
# Variáveis removidas por ter quantidade de preenchimento menor que 50%:
#
# * implementacao
# * volume_de_admissoes_mensal
# * numero_de_funcionarios
# * won_time
# * interesse
# * motivo_de_perda_detalhado
# * last_email_received
# * last_email_sent
# * mercado*
# * expectativa_de_produto
# * banco_parceiro_pgt
# * next_activity_date
# * probability
# * qtd_clts
# * sistema_de_folha_de_pgto
# * sistema_de_ponto
# * source
# * source1
# * tem_adiantamento
# * tem_conta
#
# \* Talvez juntar com outra base através do email, pessoas de contato, nome da empresa etc, para evitar a perda dessa variável.

# %%
def dropLessThan50Percent(column):
    global df_deals
    if df_deals[column].isna().sum() > df_deals.shape[0]/2:
        df_deals = df_deals.drop(column, axis=1)
    
for column in df_deals.columns:
    dropLessThan50Percent(column)

# %% [markdown]
# Variáveis removidas por outros motivos:
#
# * motivo_de_perda_detalhado: dados não estruturados*
# * owner: dados incorretos

# %%
df_deals = df_deals.drop(['owner', 'currency'], axis = 1)

# %%
df_deals.shape
# Out:
# (1843, 23)

# %% [markdown]
# Importante notar que quase 50% da base foi inutilizada por dados não estruturados, não preenchidos etc.

# %% [markdown]
# <h3><a id="value_field" class="anchor">2.2 - Ajuste do campo valor</a></h3>

# %% [markdown]
# Segregar o campo value em tipo da moeda e valor, desta forma conseguimos extrair alguns valores interessantes.
#
# * Média
# * Valor total

# %%
def retorna_valor(x):
    value = x.split(sep=' ')[0]
    value = re.sub(r'[^\w\s]','',value)
    return(value)

def retorna_moeda(x):
    return(x.split(sep=' ')[1])

df_deals['value'] = df_deals.value.apply(lambda x: retorna_valor(x)).astype('float64')/100
df_deals['weighted_value'] = df_deals.weighted_value.apply(lambda x: retorna_valor(x)).astype('float64')/100
df_deals.head(300)

# df_deals['value'].describe()
# Out:
#                   stage                                              title  \
# 0           Compromisso                                           Ipiranga
# 1    Proposta Comercial                                         Lab. Exame
# 2               Conexão                                            DTintas
# 3    Proposta Comercial                             [Contably] Três Contas
# 4    Proposta Comercial                                 [Contably] Almeida
# 5               Solução                            [BARBI] Forte Logística
# 6               Solução                               [barbi] Hotel Sandri
# 7               Solução                 [barbi] Mercado + Franquias Sandri
# 8           Diagnóstico                                           Iguatemi
# 9            Fechamento                                          Inservice
# 10              Solução                                      Vale (Xerpay)
# 11   Proposta Comercial                                       Negócio Ciee
# 12              Conexão                                  Negócio Aktie Now
# 13              Solução                        XP INVESTIMENTOS - New Deal
# 14              Conexão                                           Firework
# 15   Proposta Comercial                                        Norsk Hydro
# 16   Proposta Comercial                                            Vivante
# 17              Conexão                                   Xerpay - DM Serv
# 18              Conexão                               Contabilizei (cópia)
# 19   Proposta Comercial                                      Negócio Cobli
# 20   Proposta Comercial                                             Ocatec
# 21   Proposta Comercial                                     Negócio Caiena
# 22              Conexão                            Pescaria Industria Ltda
# 23   Proposta Comercial                                       Comunique-se
# 24           Fechamento                                               Basf
# 25         Apresentação                                       Zoom (cópia)
# 26         Apresentação                                       CON (Xerpay)
# 27   Proposta Comercial                              Lopes Sul Transportes
# 28          Diagnóstico                                             Caiena
# 29              Conexão                           Diniz moreira Engenharia
# 30              Conexão                                          Lider Tel
# 31         Apresentação                                    IDwall (Xerpay)
# 32   Proposta Comercial                                           Parafuzo
# 33           Fechamento                                    Mercado BitCoin
# 34              Conexão                                     Atria Serviços
# 35              Solução                      Security Segurança e Serviços
# 36           Fechamento                                               FIDI
# 37   Proposta Comercial                         Negócio Teresa Perez Tours
# 38   Proposta Comercial                                    4all Tecnologia
# 39   Proposta Comercial                                                UOL
# 40           Fechamento                              HF Dantas Construtora
# 41          Diagnóstico                                              Segna
# 42         Apresentação                                   Animasom (cópia)
# 43   Proposta Comercial                          Negócio Robmak Engenharia
# 44   Proposta Comercial                                           Centauro
# 45          Diagnóstico                  [adivisor bpo] cliente indefinido
# 46          Diagnóstico                                [FDM Contábil] Lime
# 47              Solução                                          Ponto Tel
# 48              Solução                                           Softplan
# 49         Apresentação                         GT3 Cup Challenge (Xerpay)
# 50         Apresentação                          Control Serviços (Xerpay)
# 51             Proposta                                    ACE Consultoria
# 52              Conexão                                                BWG
# 53              Conexão                                   NUMERO 1 SEGUROS
# 54   Proposta Comercial                                              Elsys
# 55         Apresentação                         Bridge Consulting (Xerpay)
# 56   Proposta Comercial                                CIFAL DISTRIBUIDORA
# 57          Compromisso                                  Minas Ferramentas
# 58         Apresentação                                Conta Azul (Xerpay)
# 59   Proposta Comercial                                             Vizeme
# 60              Conexão                                  Apiários Girassol
# 61          Compromisso                                             Sicoob
# 62   Proposta Comercial                                             Vector
# 63              Conexão               Negócio Tokio Marine Seguradora S.A.
# 64   Proposta Comercial                           Deutsche Schule Curitiba
# 65   Proposta Comercial                                               Coop
# 66         Apresentação                 Inteligente Contabilidade (Xerpay)
# 67          Compromisso                                           Siteware
# 68              Conexão                     Primee Serviços Especializados
# 69         Apresentação                         Xerpay - Nextel (Prospect)
# 70         Apresentação                                    Xerpay - Liv Up
# 71    Validação Técnica                            Xerpay - Grupo Baumgart
# 72          Compromisso                                            Thalent
# 73          Compromisso                                      Ogilvy Brasil
# 74         Apresentação                                  Labormed (Xerpay)
# 75   Proposta Comercial                                     Grupo Positivo
# 76          Compromisso                                Gávea Investimentos
# 77              Solução                                        Magic Games
# 78         Apresentação                            Hospital Geral (Xerpay)
# 79   Proposta Comercial                                    Madeira Madeira
# 80   Proposta Comercial                                             PicPay
# 81   Proposta Comercial                                              Mobly
# 82         Apresentação                                 CAEP Labs (Xerpay)
# 83         Apresentação                                     Magazine Luiza
# 84              Conexão                                            PJ Bank
# 85          Compromisso                                         Kley Hertz
# 86              Conexão                                           LucyHome
# 87              Conexão                                        Poupa Farma
# 88              Conexão                                             Sawary
# 89              Conexão                                        Folha Certa
# 90              Conexão                                          BR Supply
# 91          Diagnóstico                                       Transamerica
# 92          Diagnóstico                                          VR Brasil
# 93              Solução                 Negócio Burger King Brasil (cópia)
# 94              Solução                Laticinios Bela Vista (Piracanjuba)
# 95              Conexão                                             CRC-BA
# 96              Conexão                                  CPA Contabilidade
# 97              Conexão                                Inove Contabilidade
# 98              Conexão                                          Juntos RH
# 99              Conexão                                      Grupo Disfort
# 100             Conexão                                          GP Result
# 101             Conexão                                              Atlas
# 102             Conexão                              Contábil Bandeirantes
# 103             Conexão                                   Zloti Assessoria
# 104             Conexão                Negócio 5F Cloud Tecnologia (cópia)
# 105             Conexão                                  LNV CONTABILIDADE
# 106             Conexão                         CONTEC ASSESSORIA CONTABIL
# 107             Conexão                  Negócio Super Condomínios (cópia)
# 108             Conexão                        oliveira servicos contabeis
# 109             Conexão                              Domínio contabilidade
# 110             Conexão                                ALPHA CONTABILIDADE
# 111             Conexão                MC MONTENEGRO CONTABILIDADE LTDA ME
# 112          Descoberta                                  MBA Contabilidade
# 113  Proposta Comercial                                           Inovepro
# 114          Fechamento                                         Intelipost
# 115             Conexão                                  Colégio Paulicéia
# 116             Conexão                                                DHL
# 117             Conexão                                          Banco pan
# 118             Conexão                                         Casa&Vídeo
# 119         Compromisso                                           Tabmedia
# 120             Conexão                                Bispharma Packaging
# 121  Proposta Comercial                                    Quality Service
# 122  Proposta Comercial                                   Fontes Promotora
# 123  Proposta Comercial                  Admissão Bloomin Brands (Outback)
# 124         Compromisso                                             Gofind
# 125             Conexão                                       Master Infra
# 126  Proposta Comercial                                              Cteep
# 127         Compromisso         Transvipmax Portaria e Serviços de Limpeza
# 128             Conexão                                     Grupo Valdivia
# 129         Compromisso                                           Macrolub
# 130  Proposta Comercial                    Escal Contabilidade Empresarial
# 131          Fechamento                                Piloto - Forever 21
# 132             Conexão                                          Grupo DRK
# 133         Diagnóstico                                 SulAmérica Seguros
# 134         Compromisso                         SAS Plataforma de Educação
# 135             Conexão                                     Domínio pizzas
# 136             Solução                                        VR Montagem
# 137  Proposta Comercial                                              GhFly
# 138             Conexão                                Wizard - Fraqueadas
# 139             Solução                                          Assertiva
# 140          Fechamento                                      Locus Eventus
# 141         Compromisso                                  Doctoralia Brasil
# 142         Diagnóstico                                    Ingresso Rápido
# 143             Conexão                                Vocal Contabilidade
# 144         Diagnóstico                                                NTS
# 145  Proposta Comercial                                    Target sistemas
# 146          Descoberta                                               Tiex
# 147         Diagnóstico                           Supremo Tribunal Federal
# 148             Conexão                                         3 Corações
# 149             Solução                             Tsea Energia (Toshiba)
# 150             Conexão                                               Hash
# 151             Conexão                                       DECORA DOCES
# 152             Conexão        Negócio Sertrading: Importação e exportação
# 153             Conexão                        Negócio ENGESPAR ENGENHARIA
# 154         Compromisso                                      Total Express
# 155         Compromisso                                             Knewin
# 156         Compromisso               Monitora Soluções Tecnológicas Ltda.
# 157          Fechamento                                         GRUPO LEDS
# 158  Proposta Comercial                                         Koosmetics
# 159  Proposta Comercial                                  Centro de Genomas
# 160         Compromisso                                           Sensedia
# 161  Proposta Comercial                                      MRO Logistics
# 162         Diagnóstico                                        Banco Safra
# 163             Solução                                       Grupo Malwee
# 164             Conexão                                            Colombo
# 165             Conexão                              Negócio Crédito Folha
# 166             Solução                                      VLI LOGISTICA
# 167          Fechamento                          D/ARAÚJO COMUNICAÇÃO LTDA
# 168             Conexão                                              Stone
# 169             Conexão                                            Infotel
# 170             Conexão                                              CETEC
# 171             Conexão                                             Hering
# 172             Conexão                                       Hotel unique
# 173  Proposta Comercial                Negócio Leroy Merlin Brasil (cópia)
# 174             Conexão                                            Softcon
# 175         Compromisso                                       FTD Educação
# 176             Conexão                                        Grupo Oyama
# 177             Conexão                                   Toder Embalagens
# 178  Proposta Comercial                                               APMP
# 179  Proposta Comercial                                           ArcTouch
# 180             Conexão                                              Adyen
# 181  Proposta Comercial                                        Contentools
# 182             Solução                               INTERNATIONAL SCHOOL
# 183         Diagnóstico                                  Grupo Deny Sports
# 184         Compromisso                                           Rentcars
# 185             Conexão                                     (KENY) MetLife
# 186  Proposta Comercial                                    Moip Pagamentos
# 187         Compromisso                                         Telhanorte
# 188             Solução                         Negócio Mercado Eletrônico
# 189             Conexão                                 1000 MARCAS EIRELI
# 190         Compromisso                                             Fibrax
# 191             Conexão                          Zebu Carnes supermercados
# 192             Solução                                             Adecco
# 193             Conexão                            KPMG - Projeto especial
# 194             Conexão                       Negócio Saudalys Franchising
# 195             Conexão  (KENY) Negócio Nefrocare & Eloforte Serviços d...
# 196  Proposta Comercial                                  Fundação Butantan
# 197             Conexão               (KENY) BX NEGÓCIOS INTELIGENTES LTDA
# 198  Proposta Comercial                                      In Loco Media
# 199  Proposta Comercial                                         Grupo ITSS
# 200  Proposta Comercial                     Regazzo Soluções em Tecnologia
# 201  Proposta Comercial                                     Somos Educação
# 202         Compromisso                                      CI&T SOFTWARE
# 203             Conexão                                           Movement
# 204             Conexão                                            Brudden
# 205         Compromisso                                        CP Business
# 206             Conexão     Grupo CRM - Kopenhagen/Chocolates Brasil Cacau
# 207             Solução                                     Sodexo Cartões
# 208  Proposta Comercial                                            Alto Qi
# 209             Solução                                        Sebrae (PR)
# 210  Proposta Comercial                                         Geointegra
# 211             Conexão                                              SPfly
# 212             Solução                     Negócio Itaipu Transformadores
# 213             Conexão                                              Loggi
# 214         Compromisso                              Negócio Lapa Serviços
# 215             Solução                                    Negócio Partyou
# 216  Proposta Comercial                                             Zup IT
# 217             Conexão                               Santa Rita Refeições
# 218  Proposta Comercial                                          Evertical
# 219             Solução                                    IIN Tecnologias
# 220             Conexão                           Chenut Oliveira Santiago
# 221         Diagnóstico                                           BBMapfre
# 222         Compromisso                             IC Transportes (cópia)
# 223             Conexão                                       Negócio Petz
# 224             Conexão                                        SERGIPE WEB
# 225             Solução                                             InGaia
# 226             Solução                                     JCA CONTADORES
# 227             Conexão                                                cfx
# 228             Conexão                                   Scaranza Fashion
# 229             Solução                                        Banco VW FS
# 230  Proposta Comercial                                            Renovva
# 231  Proposta Comercial                                            JobHome
# 232             Conexão                                   ELDORADO PAINEIS
# 233         Compromisso                                             Plasac
# 234             Solução                           Negócio ZEN S.A. (cópia)
# 235  Proposta Comercial                            Escola Pedacinho do Céu
# 236  Proposta Comercial                           João Elias Contabilidade
# 237             Conexão                                            MOVMENT
# 238             Conexão                                         Bgmrodotec
# 239             Conexão                              CRA LINDOSO EIRELI ME
# 240         Compromisso                                          De Nigris
# 241         Compromisso                                        Le Postiche
# 242             Conexão                                   Negócio ClickBus
# 243  Proposta Comercial                 Negócio Solution Facilities Brasil
# 244         Compromisso                                    Pinturas Isocor
# 245         Compromisso                                        HOCUS POCUS
# 246             Conexão                                MEDSUL MEDICAMENTOS
# 247             Solução                                             Fareva
# 248         Compromisso                                       Construdecor
# 249             Conexão                               Wedson Contabilidade
# 250  Proposta Comercial                          KN Designer & Comunicação
# 251             Conexão                    peters burger hamburgueria ltda
# 252             Solução                                              TOTVS
# 253             Solução               Negócio Tokio Marine Seguradora S.A.
# 254             Solução                                         DFA Brasil
# 255             Solução                  Flex Relacionamentos Inteligentes
# 256             Solução                                 Linde Gases Brasil
# 257          Fechamento                                         Tracker Up
# 258             Conexão                                               mtec
# 259         Compromisso                          Full - Paradigma Serviços
# 260             Conexão                                   iBlue Consulting
# 261             Solução                                  THT contabilidade
# 262         Compromisso                                             Hirota
# 263             Solução                                       djt serviços
# 264  Proposta Comercial                           BO PACKAGING BRASIL LTDA
# 265  Proposta Comercial                                       Negócio daju
# 266         Compromisso                                             Edools
# 267         Compromisso                                 Agencia Lookn Feel
# 268             Conexão                      Negócio Extrafarma SA (cópia)
# 296     0.0  2018-09-03 17:49:57  Canal Direto
# 297  8000.0  2017-01-13 18:48:00  Canal Direto
# 298   240.0  2018-09-14 14:59:42  Canal Direto
# 299    99.0  2018-08-31 15:49:12  Canal Direto
#
#                            lost_reason                         origem_do_deal  \
# 0          Não atendeu as expectativas                                Inbound
# 1          Não atendeu as expectativas                                Inbound
# 2                       Não tem budget                                Inbound
# 3          parceiro não avançou com op                              Parcerias
# 4          parceiro não avançou com op                              Parcerias
# 5          parceiro não avançou com op                              Parcerias
# 6          parceiro não avançou com op                              Parcerias
# 7                Parceiro não engajado                              Parcerias
# 8                 Não é uma prioridade                               Outbound
# 9                 Não é uma prioridade                                Inbound
# 10         Não atendeu as expectativas                                Eventos
# 11                Não é uma prioridade                                Inbound
# 12         Não atendeu as expectativas                               Outbound
# 13                Não é uma prioridade                                    NaN
# 14                         Sem contato                                Inbound
# 15        Não estão avaliando proposta                                Inbound
# 16          Perdemos para concorrência                                Eventos
# 17                Não é uma prioridade                         Upsell na base
# 18                         Sem contato                         Upsell na base
# 19                Não é uma prioridade                                Inbound
# 20         Não atendeu as expectativas                                Inbound
# 21         Não atendeu as expectativas                               Outbound
# 22                Não é uma prioridade                                Inbound
# 23                Não é uma prioridade                                Inbound
# 24                Não é uma prioridade                                Inbound
# 25          Perdemos para concorrência                         Upsell na base
# 26                Não é uma prioridade                         Upsell na base
# 27                Não é uma prioridade                                Inbound
# 28                           duplicado                                Inbound
# 29                Não é uma prioridade                                Inbound
# 30                Não é uma prioridade                                Inbound
# 31            Não atende os requisitos                         Upsell na base
# 32                Não é uma prioridade                                Inbound
# 33                Não é uma prioridade                                Inbound
# 34         Não atendeu as expectativas                                Inbound
# 35         Não atendeu as expectativas  Entrou em contato (Intercom/Telefone)
# 36                               folha                           SDR Outbound
# 37                Não é uma prioridade  Entrou em contato (Intercom/Telefone)
# 38         Não atendeu as expectativas                                Inbound
# 39          Perdemos para concorrência                              Parcerias
# 40         Não atendeu as expectativas                              Indicação
# 41          Perdemos para concorrência  Entrou em contato (Intercom/Telefone)
# 42                Não é uma prioridade                         Upsell na base
# 43                Não é uma prioridade                              Indicação
# 44                Não é uma prioridade                                Inbound
# 45                Não é uma prioridade                              Parcerias
# 46                Não é uma prioridade                              Parcerias
# 47                      Não tem perfil                                Inbound
# 48                Não é uma prioridade                                Inbound
# 49                Não é uma prioridade                         Upsell na base
# 50                Não é uma prioridade                         Upsell na base
# 51                         sem contato                                Inbound
# 52                         sem contato                                    NaN
# 53                         Sem contato                                    NaN
# 54                Não é uma prioridade                                Eventos
# 55         Não atendeu as expectativas                         Upsell na base
# 56                Não é uma prioridade                                Inbound
# 57                Não é uma prioridade                                Inbound
# 58                Não é uma prioridade                         Upsell na base
# 59          Perdemos para concorrência                                Inbound
# 60                      Não tem budget                                    NaN
# 61                Não é uma prioridade                                Inbound
# 62          Perdemos para concorrência                                Inbound
# 63                Não é uma prioridade                                    NaN
# 64                      Não tem budget                                Inbound
# 65                      Não tem budget                                Eventos
# 66                      Não tem perfil                         Upsell na base
# 67          Perdemos para concorrência                                Inbound
# 68                      Não tem perfil                                Inbound
# 69                Não é uma prioridade                                Eventos
# 70           Não acha que é o momento.                         Upsell na base
# 71                Não é uma prioridade                         Upsell na base
# 72                        não informou                                Inbound
# 73                Não é uma prioridade                                Inbound
# 74         Não atendeu as expectativas                         Upsell na base
# 75                Não é uma prioridade                           SDR Outbound
# 76         Não atendeu as expectativas                                Inbound
# 77                Não é uma prioridade                                Inbound
# 78                Não é uma prioridade                         Upsell na base
# 79                Não é uma prioridade                                Inbound
# 80                      Não tem budget                                Inbound
# 81          Perdemos para concorrência  Entrou em contato (Intercom/Telefone)
# 82                Não é uma prioridade                         Upsell na base
# 83                Não é uma prioridade                                Inbound
# 84                         Sem contato                               Outbound
# 85                Não é uma prioridade                                Inbound
# 86                         Sem contato                               Outbound
# 87                         Sem contato                               Outbound
# 88                         Sem contato                               Outbound
# 89     susan.gracioli@citrosuco.com.br                               Outbound
# 90                         Sem contato                               Outbound
# 91                         Sem Contato                               Outbound
# 92                Não é uma prioridade                               Outbound
# 93                         Sem Contato                           SDR Outbound
# 94                         Sem Contato                                Inbound
# 95                         Sem Contato                                    NaN
# 96                         Sem Contato                                    NaN
# 97                         Sem Contato                                    NaN
# 98                         Sem Contato                                    NaN
# 99                         Sem Contato                                    NaN
# 100                        Sem Contato                                    NaN
# 101                        Sem Contato                                    NaN
# 102                        Sem Contato                                    NaN
# 103                       Sem Contatof                                    NaN
# 104                        Sem Contato  Entrou em contato (Intercom/Telefone)
# 105                        Sem Contato                                Inbound
# 106                        Sem Contato                                Inbound
# 107                        Sem Contato  Entrou em contato (Intercom/Telefone)
# 108                        Sem Contato                                Inbound
# 109                        Sem Contato                                Inbound
# 110                        Sem Contato                                Inbound
# 111                        Sem Contato                                Inbound
# 112                        sem contato                                    NaN
# 113               Não é uma prioridade                                Inbound
# 114                     Não tem budget                                Inbound
# ...
# 29   2019-01-07 11:45:37  Entire company           40.50
# 30   2019-01-09 11:24:06  Entire company          270.00
# 31   2019-01-09 10:31:49  Entire company            0.00
# 32   2019-01-21 11:47:24  Entire company          162.00
# 33   2019-01-14 16:46:55  Entire company          336.60
# 34   2019-01-17 12:51:37  Entire company            0.00
# 35   2019-01-03 15:25:39  Entire company         1620.00
# 36   2019-01-11 16:50:30  Entire company          880.00
# 37   2019-01-03 10:17:41  Entire company          945.00
# 38   2019-01-17 12:52:41  Entire company          675.00
# 39   2018-12-28 18:05:46  Entire company         1491.75
# 40   2019-01-04 10:00:02  Entire company          572.00
# 41   2018-12-27 14:08:42  Entire company           26.00
# 42   2018-12-27 14:10:15  Entire company          875.00
# 43   2018-12-26 10:59:15  Entire company          243.00
# 44   2019-01-16 17:12:38  Entire company          486.00
# 45   2019-01-23 10:24:38  Entire company            0.00
# 46   2019-01-23 10:24:37  Entire company            0.00
# 47   2018-12-18 15:34:10  Entire company          121.50
# 48   2019-01-09 17:10:09  Entire company          540.00
# 280  2018-10-01 16:46:16  Entire company            0.00
# 281  2018-10-01 15:55:31  Entire company            0.00
# 282  2018-10-29 17:15:14  Entire company          153.00
# 283  2018-11-13 21:10:47  Entire company          810.00
# 284  2019-01-17 12:37:53  Entire company          229.50
# 285  2018-09-27 13:23:28  Entire company            0.00
# 286  2018-09-27 13:17:36  Entire company            0.00
# 287  2018-09-27 11:25:18  Entire company            0.00
# 288  2018-09-26 19:04:15  Entire company            0.00
# 289  2018-09-26 19:03:56  Entire company            0.00
# 290  2018-09-26 19:03:41  Entire company            0.00
# 291  2018-09-26 17:44:06  Entire company            0.00
# 292  2018-11-07 17:40:54  Entire company          243.00
# 293  2018-09-26 13:28:50  Entire company            0.00
# 294  2018-09-26 11:28:38  Entire company            0.00
# 295  2019-01-18 14:03:29  Entire company            0.00
# 296  2018-11-13 21:10:47  Entire company            0.00
# 297  2019-01-16 10:49:57  Entire company         1440.00
# 298  2019-01-17 12:39:45  Entire company           43.20
# 299  2019-01-17 12:39:26  Entire company           25.74

# %%
df_deals.to_csv('arquivos/deals_terms_adjustment.csv', sep=';', encoding='utf-8', index=False)

# %% [markdown]
# <h3><a id="field_cases" class="anchor">2.3 - Ajuste termos semelhantes</a></h3>
#
# É possível verificar a presença de termos semelhantes, alguns exemplos:
# * Palavras escritas começando com maiúsculo ou minúsculo;
# * Palavras com acento e sem acento;
# * Palavras com espaço no fim, início etc.

# %%
def print_details(column_name):
    '''print some details of columns with object type'''
    df_temp = df_deals.loc[:,[column_name,'currency']].groupby(column_name).count().reset_index()
    df_temp = df_temp.rename(columns={'currency':'qnt'}).sort_values('qnt',ascending=False)
    print("Quantidade de categorias: ", df_temp.shape[0])
    # print(f'{df_temp} \n')

# %%
import re
from unicodedata import normalize

df_deals = pd.read_csv('arquivos/deals_terms_adjustment.csv', sep=';')
df_deals_object = df_deals.select_dtypes('object')

def filterChar(char):
    if '*' not in char or '+' not in char or '?' not in char:
        return False
    return True

def normalizeStrings(v):
    if not pd.isnull(v):
        newV = v.strip()
        newV = newV.lower()
        newV = re.sub(r'[^\w\s]','',newV)
        newV = re.sub(' ','_',newV)
        newV = normalize('NFKD', newV).encode('ASCII', 'ignore').decode('ASCII')
        return newV
    else:
        return v
    
for c in df_deals_object.columns:
    print(c)
    if c != 'deal_created' and c != 'lost_time' and c != 'last_activity_date' and c != 'last_stage_change' and c != 'expected_close_date' and c != 'deal_closed_on' and c != 'update_time':
        print_details(c)
        df_deals[c] = df_deals_object[c].apply(normalizeStrings)
        print_details(c)
    
df_deals.head()
# Out:
# stage
# Quantidade de categorias:  17
# Quantidade de categorias:  17
# title
# Quantidade de categorias:  1797
# Quantidade de categorias:  1791
# deal_created
# pipeline
# Quantidade de categorias:  4
# Quantidade de categorias:  4
# lost_reason
# Quantidade de categorias:  190
# Quantidade de categorias:  176
# origem_do_deal
# Quantidade de categorias:  8
# Quantidade de categorias:  8
# status
# Quantidade de categorias:  3
# Quantidade de categorias:  3
# lost_time
# last_activity_date
# last_stage_change
# expected_close_date
# contact_person
# Quantidade de categorias:  1490
# Quantidade de categorias:  1442
# creator
# Quantidade de categorias:  10
# Quantidade de categorias:  10
# deal_closed_on
# organization
# Quantidade de categorias:  1510
# Quantidade de categorias:  1502
# update_time
# visible_to
# Quantidade de categorias:  1
# Quantidade de categorias:  1
#                 stage                 title   value         deal_created  \
# 0         compromisso              ipiranga  1400.0  2018-11-06 18:45:30
# 1  proposta_comercial             lab_exame  1000.0  2018-12-03 14:39:50
# 2             conexao               dtintas  1950.0  2019-01-21 16:33:38
# 3  proposta_comercial  contably_tres_contas   900.0  2018-12-10 17:30:58
# 4  proposta_comercial      contably_almeida   450.0  2018-12-10 17:33:11
#
#        pipeline                  lost_reason origem_do_deal status  \
# 0  canal_direto  nao_atendeu_as_expectativas        inbound   lost
# 1  canal_direto  nao_atendeu_as_expectativas        inbound   lost
# 2  canal_direto               nao_tem_budget        inbound   lost
# 3  canal_direto  parceiro_nao_avancou_com_op      parcerias   lost
# 4  canal_direto  parceiro_nao_avancou_com_op      parcerias   lost
#
#              lost_time last_activity_date    last_stage_change  \
# 0  2019-01-23 18:03:12         2018-12-11  2018-11-12 17:12:05
# 1  2019-01-23 16:51:33         2019-01-22  2018-12-10 10:54:25
# 2  2019-01-23 11:52:06         2019-01-22                  NaN
# 3  2019-01-23 11:10:49         2019-01-21  2018-12-10 17:40:36
# 4  2019-01-23 11:10:35         2019-01-21  2018-12-10 17:34:26
#
#   expected_close_date  activities_to_do        contact_person  \
# 0          2019-02-28                 1          alice_xavier
# 1          2019-01-31                 0  elizangela_alvarenga
# 2          2019-02-28                 0                raquel
# 3          2018-12-31                 0       rafael_contably
# 4          2018-12-31                 0       rafael_contably
#
#              creator       deal_closed_on  done_activities  \
# 0    guilherme_salam  2019-01-23 18:03:12               15
# 1  henrique_carvalho  2019-01-23 16:51:33               12
# 2   tamiris_januario  2019-01-23 11:52:06                6
# 3    jose_luiz_souza  2019-01-23 11:10:49                3
# 4    jose_luiz_souza  2019-01-23 11:10:35                3
#
#    email_messages_count organization  total_activities          update_time  \
# 0                    18     ipiranga                16  2019-01-23 18:03:25
# 1                     8    lab_exame                12  2019-01-23 17:01:58
# 2                     2      dtintas                 6  2019-01-23 11:52:06
# 3                     0      cotably                 3  2019-01-23 11:10:53
# 4                     3      cotably                 3  2019-01-23 11:10:38
#
#        visible_to  weighted_value
# 0  entire_company           532.0
# 1  entire_company           540.0
# 2  entire_company           351.0
# 3  entire_company           486.0
# 4  entire_company           243.0

# %% [markdown]
# <h3><a id="light_adjustment" class="anchor">2.4 - Ajuste fino de termos</a></h3>
#
# Alguns tratamentos são mais complicados, como:
# * Termos com mesmo significado.

# %%
print_details('stage')
df_deals['stage'] = df_deals['stage'].replace({
    'proposta': 'proposta_comercial',
    'conectado': 'conexao'
})
print_details('stage')
# Out:
# Quantidade de categorias:  17
# Quantidade de categorias:  15

# %%
print_details('lost_reason')

df_deals['lost_reason'] = df_deals['lost_reason'].replace({
    'nao_e_uma_prioridade_no_momento': 'nao_e_uma_prioridade',
    'perdemos_para_um_concorrente': 'perdemos_para_concorrencia',
    'sem_resposta': 'sem_contato',
    'deixou_de_responder': 'sem_contato',
    'nao_e_prioridade': 'nao_e_uma_prioridade',
    'parou_de_responder': 'sem_contato',
    'sem_conttao': 'sem_contato'
})

print_details('lost_reason')
# Out:
# Quantidade de categorias:  176
# Quantidade de categorias:  169

# %%
# Saving current progress
df_deals.to_csv('arquivos/deals_variables_adjustment.csv', sep=';', encoding='utf-8', index=False)

# %% [markdown]
# <h2><a id="derivate_fields" class="anchor">3 - Derivação de campos</a></h2>
#
# Ajustar os campos com os seus formatos corretos, ex: converter campos númericos para números, e derivar informações que podem ser relevantes para o fenômeno.

# %%
df_deals = pd.read_csv('arquivos/deals_variables_adjustment.csv', sep=';')

print(f'Linhas e colunas: {df_deals.shape}')
df_deals.head()
# Out:
# Linhas e colunas: (1843, 23)
#                 stage                 title   value         deal_created  \
# 0         compromisso              ipiranga  1400.0  2018-11-06 18:45:30
# 1  proposta_comercial             lab_exame  1000.0  2018-12-03 14:39:50
# 2             conexao               dtintas  1950.0  2019-01-21 16:33:38
# 3  proposta_comercial  contably_tres_contas   900.0  2018-12-10 17:30:58
# 4  proposta_comercial      contably_almeida   450.0  2018-12-10 17:33:11
#
#        pipeline                  lost_reason origem_do_deal status  \
# 0  canal_direto  nao_atendeu_as_expectativas        inbound   lost
# 1  canal_direto  nao_atendeu_as_expectativas        inbound   lost
# 2  canal_direto               nao_tem_budget        inbound   lost
# 3  canal_direto  parceiro_nao_avancou_com_op      parcerias   lost
# 4  canal_direto  parceiro_nao_avancou_com_op      parcerias   lost
#
#              lost_time last_activity_date    last_stage_change  \
# 0  2019-01-23 18:03:12         2018-12-11  2018-11-12 17:12:05
# 1  2019-01-23 16:51:33         2019-01-22  2018-12-10 10:54:25
# 2  2019-01-23 11:52:06         2019-01-22                  NaN
# 3  2019-01-23 11:10:49         2019-01-21  2018-12-10 17:40:36
# 4  2019-01-23 11:10:35         2019-01-21  2018-12-10 17:34:26
#
#   expected_close_date  activities_to_do        contact_person  \
# 0          2019-02-28                 1          alice_xavier
# 1          2019-01-31                 0  elizangela_alvarenga
# 2          2019-02-28                 0                raquel
# 3          2018-12-31                 0       rafael_contably
# 4          2018-12-31                 0       rafael_contably
#
#              creator       deal_closed_on  done_activities  \
# 0    guilherme_salam  2019-01-23 18:03:12               15
# 1  henrique_carvalho  2019-01-23 16:51:33               12
# 2   tamiris_januario  2019-01-23 11:52:06                6
# 3    jose_luiz_souza  2019-01-23 11:10:49                3
# 4    jose_luiz_souza  2019-01-23 11:10:35                3
#
#    email_messages_count organization  total_activities          update_time  \
# 0                    18     ipiranga                16  2019-01-23 18:03:25
# 1                     8    lab_exame                12  2019-01-23 17:01:58
# 2                     2      dtintas                 6  2019-01-23 11:52:06
# 3                     0      cotably                 3  2019-01-23 11:10:53
# 4                     3      cotably                 3  2019-01-23 11:10:38
#
#        visible_to  weighted_value
# 0  entire_company           532.0
# 1  entire_company           540.0
# 2  entire_company           351.0
# 3  entire_company           486.0
# 4  entire_company           243.0

# %% [markdown]
# <h3><a id="value_field" class="anchor">3.1 - Derivação de datas</a></h3>
#
# Importante para conseguir entender a informação de forma segregada, ou seja, semanalmente, mensalmente, semestralmente etc.
#
# Resumidamente: a derivação de variáveis pode trazer novos dados, ou uma maneira diferente de olhar para os mesmos dados.

# %%
def derivateDate (column):
    df_deals[column + '_date'] = df_deals[column].astype('datetime64[D]')
    df_deals[column + '_year'] = df_deals[column + '_date'].apply(lambda x: x.year)
    df_deals[column + '_month'] = df_deals[column + '_date'].apply(lambda x: x.month)
    df_deals[column + '_day'] = df_deals[column + '_date'].apply(lambda x: x.day)
    df_deals[column + '_quarter'] = df_deals[column + '_date'].apply(lambda x: x.quarter)
    df_deals[column + '_weekday'] = df_deals[column + '_date'].apply(lambda x: x.dayofweek)
    df_deals.drop([column],axis=1,inplace=True)
    
derivateDate('deal_created')
derivateDate('lost_time')
derivateDate('last_activity_date')
# derivateDate('last_email_received')
# derivateDate('last_email_sent')
derivateDate('last_stage_change')
derivateDate('expected_close_date')
derivateDate('deal_closed_on')
# derivateDate('next_activity_date')
derivateDate('update_time')

df_deals.head()
# Out:
#                 stage                 title   value      pipeline  \
# 0         compromisso              ipiranga  1400.0  canal_direto
# 1  proposta_comercial             lab_exame  1000.0  canal_direto
# 2             conexao               dtintas  1950.0  canal_direto
# 3  proposta_comercial  contably_tres_contas   900.0  canal_direto
# 4  proposta_comercial      contably_almeida   450.0  canal_direto
#
#                    lost_reason origem_do_deal status  activities_to_do  \
# 0  nao_atendeu_as_expectativas        inbound   lost                 1
# 1  nao_atendeu_as_expectativas        inbound   lost                 0
# 2               nao_tem_budget        inbound   lost                 0
# 3  parceiro_nao_avancou_com_op      parcerias   lost                 0
# 4  parceiro_nao_avancou_com_op      parcerias   lost                 0
#
#          contact_person            creator  done_activities  \
# 0          alice_xavier    guilherme_salam               15
# 1  elizangela_alvarenga  henrique_carvalho               12
# 2                raquel   tamiris_januario                6
# 3       rafael_contably    jose_luiz_souza                3
# 4       rafael_contably    jose_luiz_souza                3
#
#    email_messages_count organization  total_activities      visible_to  \
# 0                    18     ipiranga                16  entire_company
# 1                     8    lab_exame                12  entire_company
# 2                     2      dtintas                 6  entire_company
# 3                     0      cotably                 3  entire_company
# 4                     3      cotably                 3  entire_company
#
#    weighted_value deal_created_date  deal_created_year  deal_created_month  \
# 0           532.0        2018-11-06               2018                  11
# 1           540.0        2018-12-03               2018                  12
# 2           351.0        2019-01-21               2019                   1
# 3           486.0        2018-12-10               2018                  12
# 4           243.0        2018-12-10               2018                  12
#
#    deal_created_day  deal_created_quarter  deal_created_weekday  \
# 0                 6                     4                     1
# 1                 3                     4                     0
# 2                21                     1                     0
# 3                10                     4                     0
# 4                10                     4                     0
#
#   lost_time_date  lost_time_year  lost_time_month  lost_time_day  \
# 0     2019-01-23          2019.0              1.0           23.0
# 1     2019-01-23          2019.0              1.0           23.0
# 2     2019-01-23          2019.0              1.0           23.0
# 3     2019-01-23          2019.0              1.0           23.0
# 4     2019-01-23          2019.0              1.0           23.0
#
#    lost_time_quarter  lost_time_weekday last_activity_date_date  \
# 0                1.0                2.0              2018-12-11
# 1                1.0                2.0              2019-01-22
# 2                1.0                2.0              2019-01-22
# 3                1.0                2.0              2019-01-21
# 4                1.0                2.0              2019-01-21
#
#    last_activity_date_year  last_activity_date_month  last_activity_date_day  \
# 0                   2018.0                      12.0                    11.0
# 1                   2019.0                       1.0                    22.0
# 2                   2019.0                       1.0                    22.0
# 3                   2019.0                       1.0                    21.0
# 4                   2019.0                       1.0                    21.0
#
#    last_activity_date_quarter  last_activity_date_weekday  \
# 0                         4.0                         1.0
# 1                         1.0                         1.0
# 2                         1.0                         1.0
# 3                         1.0                         0.0
# 4                         1.0                         0.0
#
#   last_stage_change_date  last_stage_change_year  last_stage_change_month  \
# 0             2018-11-12                  2018.0                     11.0
# 1             2018-12-10                  2018.0                     12.0
# 2                    NaT                     NaN                      NaN
# 3             2018-12-10                  2018.0                     12.0
# 4             2018-12-10                  2018.0                     12.0
#
#    last_stage_change_day  last_stage_change_quarter  \
# 0                   12.0                        4.0
# 1                   10.0                        4.0
# 2                    NaN                        NaN
# 3                   10.0                        4.0
# 4                   10.0                        4.0
#
#    last_stage_change_weekday expected_close_date_date  \
# 0                        0.0               2019-02-28
# 1                        0.0               2019-01-31
# 2                        NaN               2019-02-28
# 3                        0.0               2018-12-31
# 4                        0.0               2018-12-31
#
#    expected_close_date_year  expected_close_date_month  \
# 0                    2019.0                        2.0
# 1                    2019.0                        1.0
# 2                    2019.0                        2.0
# 3                    2018.0                       12.0
# 4                    2018.0                       12.0
#
#    expected_close_date_day  expected_close_date_quarter  \
# 0                     28.0                          1.0
# 1                     31.0                          1.0
# 2                     28.0                          1.0
# 3                     31.0                          4.0
# 4                     31.0                          4.0
#
#    expected_close_date_weekday deal_closed_on_date  deal_closed_on_year  \
# 0                          3.0          2019-01-23               2019.0
# 1                          3.0          2019-01-23               2019.0
# 2                          3.0          2019-01-23               2019.0
# 3                          0.0          2019-01-23               2019.0
# 4                          0.0          2019-01-23               2019.0
#
#    deal_closed_on_month  deal_closed_on_day  deal_closed_on_quarter  \
# 0                   1.0                23.0                     1.0
# 1                   1.0                23.0                     1.0
# 2                   1.0                23.0                     1.0
# 3                   1.0                23.0                     1.0
# 4                   1.0                23.0                     1.0
#
#    deal_closed_on_weekday update_time_date  update_time_year  \
# 0                     2.0       2019-01-23              2019
# 1                     2.0       2019-01-23              2019
# 2                     2.0       2019-01-23              2019
# 3                     2.0       2019-01-23              2019
# 4                     2.0       2019-01-23              2019
#
#    update_time_month  update_time_day  update_time_quarter  \
# 0                  1               23                    1
# 1                  1               23                    1
# 2                  1               23                    1
# 3                  1               23                    1
# 4                  1               23                    1
#
#    update_time_weekday
# 0                    2
# 1                    2
# 2                    2
# 3                    2
# 4                    2

# %% [markdown]
# <h2><a id="outliers" class="anchor">4 - Eliminação de outliers</a></h2>

# %%
# Eliminar outliers
# Dados faltantes (substituição ou exclusão)
# df_deals['mercado'] = df_deals['mercado'].fillna('Outros')

# modelos supervisionados e não supervisionados
# supervisionado: 
# buscar variáveis relacionadsa ao evento que eu tenho interesse
# variáveis que ocorrem depois do lead são irrelevantes
# variáveis independentes ao femomeno 

# conhecer o processo, estatística, e programação

# lost reason não importa, porque tem relação com o porquê o lead foi perdido, 
# nós apenas queremos saber se temos ele perdido

# time series - modelo temporal

# a dericação das datas ocorrem para conseguir encontrar padrões de repetição

# loc ? how to use that thing?

# plano completo, é apena plano completo
# check outliers

# think about storytelling
# 1 - base inicial
# explicar quantas colunas temos, tipos de variáveis, categóricas ou numéricas
# 2 - explicar a limpeza dos dados
# harmonizar variáveis, categóricas, numéricas, etc
# 3 - gráficos interessantes
# mostrar % de variáveis completas e não completas
# 4 - variáveis derivadas
# variáveis finais
# 5 - Conscientizar para zelar pelas informações
# mostrar exemplos bizarros

# %%
# LabelEncoder:
from sklearn.preprocessing import LabelEncoder

lb_make = LabelEncoder()

df_deals_merc = df_deals[df_deals['mercado'].notnull()] 
print(df_deals.shape)
print(df_deals_merc.shape)

# df_deals['mercado_lb'] = lb_make.fit_transform(df_deals['mercado'])
# df_deals_merc['mercado_lb'] = lb_make.fit_transform(df_deals_merc['mercado'])

# %%
# HotEncoding:
df_deals_merc = pd.get_dummies(df_deals_merc, columns=['mercado'], prefix = ['hot_mercado'])
print(df_deals.shape)
print(df_deals_merc.shape)
df_deals_merc.head()

# %%
import numpy as np

df_deals_num = df_deals.select_dtypes(['float64','int64'])
df_deals_num.dtypes

# Distribuição:
bins = 10
var = 'implementacao'

bin_values = np.arange(start=df_deals_num[var].min(), 
                       stop=df_deals_num[var].max(), 
                       step=((df_deals_num[var].max()-df_deals_num[var].min())/bins))

# %%
## chart about implementacao numbers
df_deals_num[var].hist(bins=bin_values, figsize=[14,6])

# %%
# BoxPlot:
import seaborn as sns
 
# Make boxplot for one group only

sns.boxplot(y=df_deals_num["update_time_month"])
sns.boxplot(y=df_deals_num["value"])
sns.boxplot(y=df_deals_num["implementacao"])
sns.boxplot(y=df_deals_num["volume_de_admissoes_mensal"])
sns.boxplot(y=df_deals_num["numero_de_funcionarios"])
sns.boxplot(y=df_deals_num["activities_to_do"])
sns.boxplot(y=df_deals_num["done_activities"])
sns.boxplot(y=df_deals_num["email_messages_count"])
sns.boxplot(y=df_deals_num["probability"])
sns.boxplot(y=df_deals_num["source"])
sns.boxplot(y=df_deals_num["source1"])
sns.boxplot(y=df_deals_num["total_activities"])

print(df_deals_num.shape)
df_deals_num_filter = df_deals_num[df_deals_num['numero_de_funcionarios'] <= 1000]
print(df_deals_num_filter.shape)
sns.boxplot(y=df_deals_num["numero_de_funcionarios"])
sns.boxplot(y=df_deals_num_filter["numero_de_funcionarios"])
